# %% [markdown]
# # Survival Analysis

# %%
# Import Packages:
using Pkg
Pkg.add("CSV")
Pkg.add("DataFrames")
Pkg.add("StatsBase")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
# Read the CSV File:
using CSV
using DataFrames
using Dates
using Plots

# %%
# Load the CSV file
file_path = "../data/AbsenceList_SampleData.csv"  # Update with the correct file path
data = CSV.File(file_path, delim='\t') |> DataFrame
# Out:
# 50×8 DataFrame
#  Row │ Full name  First name  ID       Class    Start date    Start time  End  ⋯
#      │ String7    String7     Missing  String7  String15      String15    Stri ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Last01     First01     missing  CS101    Sep 27, 2023  8:30 AM     Sep  ⋯
#    2 │ Last01     First01     missing  CS101    Sep 27, 2023  1:15 PM     Sep
#    3 │ Last01     First01     missing  CS101    Sep 29, 2023  1:15 PM     Sep
#    4 │ Last01     First01     missing  CS101    Oct 3, 2023   8:30 AM     Oct
#    5 │ Last01     First01     missing  CS101    Oct 3, 2023   9:25 AM     Oct  ⋯
#    6 │ Last01     First01     missing  CS101    Dec 8, 2023   1:15 PM     Dec
#    7 │ Last02     First02     missing  CS101    Oct 3, 2023   8:55 AM     Oct
#    8 │ Last02     First02     missing  CS101    Oct 9, 2023   1:15 PM     Oct
#    9 │ Last02     First02     missing  CS101    Oct 10, 2023  8:30 AM     Oct  ⋯
#   10 │ Last02     First02     missing  CS101    Oct 10, 2023  1:15 PM     Oct
#   11 │ Last02     First02     missing  CS101    Oct 11, 2023  1:15 PM     Oct
#   ⋮  │     ⋮          ⋮          ⋮        ⋮          ⋮            ⋮            ⋱
#   41 │ Last08     First08     missing  CS101    Oct 27, 2023  1:15 PM     Oct
#   42 │ Last08     First08     missing  CS101    Nov 21, 2023  8:30 AM     Nov  ⋯
#   43 │ Last09     First09     missing  CS101    Sep 22, 2023  1:15 PM     Sep
#   44 │ Last09     First09     missing  CS101    Sep 29, 2023  1:15 PM     Sep
#   45 │ Last09     First09     missing  CS101    Oct 4, 2023   10:30 AM    Oct
#   46 │ Last09     First09     missing  CS101    Oct 13, 2023  10:30 AM    Oct  ⋯
#   47 │ Last10     First10     missing  CS101    Oct 4, 2023   8:30 AM     Oct
#   48 │ Last10     First10     missing  CS101    Oct 13, 2023  8:30 AM     Oct
#   49 │ Last10     First10     missing  CS101    Oct 20, 2023  8:30 AM     Oct
#   50 │ Last10     First10     missing  CS101    Oct 20, 2023  1:15 PM     Oct  ⋯
#                                                    2 columns and 29 rows omitted

# %% [markdown]
# ## Create a new date variable for "Start date"
# This step is necessary as the variable is not standard and therefore not recognized by the "Date" package.

# %%
# Extract the last 4 characters of "Start date" and create a new column "Year"
data[!, "Year"] = last.(string.(data[!, "Start date"]), 4)

# Extract the first 5 characters of "Start date" and create a new column "First5Chars"
data[!, "First5Chars"] = first.(string.(data[!, "Start date"]), 6)

# Remove the comma from "First5Chars" and update the column
data[!, "First5Chars"] = replace.(data[!, "First5Chars"], "," => "")

# Extract the first three characters of "First5Chars" and create a new column "Month"
data[!, "Month"] = first.(string.(data[!, "First5Chars"]), 3)

# Extract the last two characters of "First5Chars" and create a new column "Day"
data[!, "Day"] = last.(string.(data[!, "First5Chars"]), 2)


# Define a dictionary to map month abbreviations to numerical values
month_dict = Dict("Jan" => 1, "Feb" => 2, "Mar" => 3, "Apr" => 4, "May" => 5, "Jun" => 6, "Jul" => 7, "Aug" => 8, "Sep" => 9, "Oct" => 10, "Nov" => 11, "Dec" => 12)

# Create a new column "MonthNumeric" by mapping the month abbreviations to numerical values
data[!, "MonthNumeric"] = [month_dict[strip(string(month))] for month in data[!, "Month"]]

# Create a new column "NewDate" by combining "Year," "MonthNumeric," and "Day"
data[!, "StartDate"] = Dates.Date.(parse.(Int, data[!, "Year"]), data[!, "MonthNumeric"], parse.(Int, data[!, "Day"]))

# Suppose you want to delete columns "Month" and "Year"
select!(data, Not(:Month, :Year, :Day, :First5Chars, :MonthNumeric  ))
# Out:
# 50×9 DataFrame
#  Row │ Full name  First name  ID       Class    Start date    Start time  End  ⋯
#      │ String7    String7     Missing  String7  String15      String15    Stri ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Last01     First01     missing  CS101    Sep 27, 2023  8:30 AM     Sep  ⋯
#    2 │ Last01     First01     missing  CS101    Sep 27, 2023  1:15 PM     Sep
#    3 │ Last01     First01     missing  CS101    Sep 29, 2023  1:15 PM     Sep
#    4 │ Last01     First01     missing  CS101    Oct 3, 2023   8:30 AM     Oct
#    5 │ Last01     First01     missing  CS101    Oct 3, 2023   9:25 AM     Oct  ⋯
#    6 │ Last01     First01     missing  CS101    Dec 8, 2023   1:15 PM     Dec
#    7 │ Last02     First02     missing  CS101    Oct 3, 2023   8:55 AM     Oct
#    8 │ Last02     First02     missing  CS101    Oct 9, 2023   1:15 PM     Oct
#    9 │ Last02     First02     missing  CS101    Oct 10, 2023  8:30 AM     Oct  ⋯
#   10 │ Last02     First02     missing  CS101    Oct 10, 2023  1:15 PM     Oct
#   11 │ Last02     First02     missing  CS101    Oct 11, 2023  1:15 PM     Oct
#   ⋮  │     ⋮          ⋮          ⋮        ⋮          ⋮            ⋮            ⋱
#   41 │ Last08     First08     missing  CS101    Oct 27, 2023  1:15 PM     Oct
#   42 │ Last08     First08     missing  CS101    Nov 21, 2023  8:30 AM     Nov  ⋯
#   43 │ Last09     First09     missing  CS101    Sep 22, 2023  1:15 PM     Sep
#   44 │ Last09     First09     missing  CS101    Sep 29, 2023  1:15 PM     Sep
#   45 │ Last09     First09     missing  CS101    Oct 4, 2023   10:30 AM    Oct
#   46 │ Last09     First09     missing  CS101    Oct 13, 2023  10:30 AM    Oct  ⋯
#   47 │ Last10     First10     missing  CS101    Oct 4, 2023   8:30 AM     Oct
#   48 │ Last10     First10     missing  CS101    Oct 13, 2023  8:30 AM     Oct
#   49 │ Last10     First10     missing  CS101    Oct 20, 2023  8:30 AM     Oct
#   50 │ Last10     First10     missing  CS101    Oct 20, 2023  1:15 PM     Oct  ⋯
#                                                    3 columns and 29 rows omitted

# %% [markdown]
# ## Create a new date variable for "End date"
# This step is necessary as the variable is not standard and therefore not recognized by the "Date" package.

# %%
# Extract the last 4 characters of "Start date" and create a new column "Year"
data[!, "Year"] = last.(string.(data[!, "End date"]), 4)

# Extract the first 5 characters of "Start date" and create a new column "First5Chars"
data[!, "First5Chars"] = first.(string.(data[!, "End date"]), 6)

# Remove the comma from "First5Chars" and update the column
data[!, "First5Chars"] = replace.(data[!, "First5Chars"], "," => "")

# Extract the first three characters of "First5Chars" and create a new column "Month"
data[!, "Month"] = first.(string.(data[!, "First5Chars"]), 3)

# Extract the last two characters of "First5Chars" and create a new column "Day"
data[!, "Day"] = last.(string.(data[!, "First5Chars"]), 2)


# Define a dictionary to map month abbreviations to numerical values
month_dict = Dict("Jan" => 1, "Feb" => 2, "Mar" => 3, "Apr" => 4, "May" => 5, "Jun" => 6, "Jul" => 7, "Aug" => 8, "Sep" => 9, "Oct" => 10, "Nov" => 11, "Dec" => 12)

# Create a new column "MonthNumeric" by mapping the month abbreviations to numerical values
data[!, "MonthNumeric"] = [month_dict[strip(string(month))] for month in data[!, "Month"]]

# Create a new column "NewDate" by combining "Year," "MonthNumeric," and "Day"
data[!, "EndDate"] = Dates.Date.(parse.(Int, data[!, "Year"]), data[!, "MonthNumeric"], parse.(Int, data[!, "Day"]))

# Suppose you want to delete columns "Month" and "Year"
select!(data, Not(:Month, :Year, :Day, :First5Chars, :MonthNumeric  ))
# Out:
# 50×10 DataFrame
#  Row │ Full name  First name  ID       Class    Start date    Start time  End  ⋯
#      │ String7    String7     Missing  String7  String15      String15    Stri ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Last01     First01     missing  CS101    Sep 27, 2023  8:30 AM     Sep  ⋯
#    2 │ Last01     First01     missing  CS101    Sep 27, 2023  1:15 PM     Sep
#    3 │ Last01     First01     missing  CS101    Sep 29, 2023  1:15 PM     Sep
#    4 │ Last01     First01     missing  CS101    Oct 3, 2023   8:30 AM     Oct
#    5 │ Last01     First01     missing  CS101    Oct 3, 2023   9:25 AM     Oct  ⋯
#    6 │ Last01     First01     missing  CS101    Dec 8, 2023   1:15 PM     Dec
#    7 │ Last02     First02     missing  CS101    Oct 3, 2023   8:55 AM     Oct
#    8 │ Last02     First02     missing  CS101    Oct 9, 2023   1:15 PM     Oct
#    9 │ Last02     First02     missing  CS101    Oct 10, 2023  8:30 AM     Oct  ⋯
#   10 │ Last02     First02     missing  CS101    Oct 10, 2023  1:15 PM     Oct
#   11 │ Last02     First02     missing  CS101    Oct 11, 2023  1:15 PM     Oct
#   ⋮  │     ⋮          ⋮          ⋮        ⋮          ⋮            ⋮            ⋱
#   41 │ Last08     First08     missing  CS101    Oct 27, 2023  1:15 PM     Oct
#   42 │ Last08     First08     missing  CS101    Nov 21, 2023  8:30 AM     Nov  ⋯
#   43 │ Last09     First09     missing  CS101    Sep 22, 2023  1:15 PM     Sep
#   44 │ Last09     First09     missing  CS101    Sep 29, 2023  1:15 PM     Sep
#   45 │ Last09     First09     missing  CS101    Oct 4, 2023   10:30 AM    Oct
#   46 │ Last09     First09     missing  CS101    Oct 13, 2023  10:30 AM    Oct  ⋯
#   47 │ Last10     First10     missing  CS101    Oct 4, 2023   8:30 AM     Oct
#   48 │ Last10     First10     missing  CS101    Oct 13, 2023  8:30 AM     Oct
#   49 │ Last10     First10     missing  CS101    Oct 20, 2023  8:30 AM     Oct
#   50 │ Last10     First10     missing  CS101    Oct 20, 2023  1:15 PM     Oct  ⋯
#                                                    4 columns and 29 rows omitted

# %% [markdown]
# ## Create a new date variable for "Start time"
# This step is necessary as the variable is not standard and therefore not recognized by the "Date" package.

# %%
starttime = data[!, "Start time"]
meridiem = last.(starttime,2)
time = first.(starttime,5)
hourtemp = first.(time,2)
minutetemp = last.(time,3)
minutetemp1 = replace.(minutetemp, ":" => "")
minutetemp2 = replace.(minutetemp1, " " => "")

hour = replace.(hourtemp, ":" => "")
minute = minutetemp2

data[!,"StartTimeHour"] = hour;
data[!,"StartTimeMinute"] = minute;
data[!,"StartTimeMeridiem"] = meridiem;

# Define as Time format
data[!,"time_format_str"] = hour .* ":" .* minute .* " " .* meridiem
data[!,"StartTime"] = Dates.Time.(data[!,"time_format_str"], dateformat"HH:MM p")

# Drop variables
select!(data, Not(:StartTimeHour, :StartTimeMinute, :StartTimeMeridiem, :time_format_str  ))
# Out:
# 50×11 DataFrame
#  Row │ Full name  First name  ID       Class    Start date    Start time  End  ⋯
#      │ String7    String7     Missing  String7  String15      String15    Stri ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Last01     First01     missing  CS101    Sep 27, 2023  8:30 AM     Sep  ⋯
#    2 │ Last01     First01     missing  CS101    Sep 27, 2023  1:15 PM     Sep
#    3 │ Last01     First01     missing  CS101    Sep 29, 2023  1:15 PM     Sep
#    4 │ Last01     First01     missing  CS101    Oct 3, 2023   8:30 AM     Oct
#    5 │ Last01     First01     missing  CS101    Oct 3, 2023   9:25 AM     Oct  ⋯
#    6 │ Last01     First01     missing  CS101    Dec 8, 2023   1:15 PM     Dec
#    7 │ Last02     First02     missing  CS101    Oct 3, 2023   8:55 AM     Oct
#    8 │ Last02     First02     missing  CS101    Oct 9, 2023   1:15 PM     Oct
#    9 │ Last02     First02     missing  CS101    Oct 10, 2023  8:30 AM     Oct  ⋯
#   10 │ Last02     First02     missing  CS101    Oct 10, 2023  1:15 PM     Oct
#   11 │ Last02     First02     missing  CS101    Oct 11, 2023  1:15 PM     Oct
#   ⋮  │     ⋮          ⋮          ⋮        ⋮          ⋮            ⋮            ⋱
#   41 │ Last08     First08     missing  CS101    Oct 27, 2023  1:15 PM     Oct
#   42 │ Last08     First08     missing  CS101    Nov 21, 2023  8:30 AM     Nov  ⋯
#   43 │ Last09     First09     missing  CS101    Sep 22, 2023  1:15 PM     Sep
#   44 │ Last09     First09     missing  CS101    Sep 29, 2023  1:15 PM     Sep
#   45 │ Last09     First09     missing  CS101    Oct 4, 2023   10:30 AM    Oct
#   46 │ Last09     First09     missing  CS101    Oct 13, 2023  10:30 AM    Oct  ⋯
#   47 │ Last10     First10     missing  CS101    Oct 4, 2023   8:30 AM     Oct
#   48 │ Last10     First10     missing  CS101    Oct 13, 2023  8:30 AM     Oct
#   49 │ Last10     First10     missing  CS101    Oct 20, 2023  8:30 AM     Oct
#   50 │ Last10     First10     missing  CS101    Oct 20, 2023  1:15 PM     Oct  ⋯
#                                                    5 columns and 29 rows omitted

# %% [markdown]
# ## Create a new date variable for "End time"
# This step is necessary as the variable is not standard and therefore not recognized by the "Date" package.

# %%
endtime = data[!, "End time"]
meridiem = last.(endtime,2)
time = first.(endtime,5)
hourtemp = first.(time,2)
minutetemp = last.(time,3)
minutetemp1 = replace.(minutetemp, ":" => "")
minutetemp2 = replace.(minutetemp1, " " => "")

hour = replace.(hourtemp, ":" => "")
minute = minutetemp2

data[!,"EndTimeHour"] = hour;
data[!,"EndTimeMinute"] = minute;
data[!,"EndTimeMeridiem"] = meridiem;

# Define as Time format
data[!,"time_format_str"] = hour .* ":" .* minute .* " " .* meridiem
data[!,"EndTime"] = Dates.Time.(data[!,"time_format_str"], dateformat"HH:MM p")

# Drop variables
select!(data, Not(:EndTimeHour, :EndTimeMinute, :EndTimeMeridiem, :time_format_str  ))
# Out:
# 50×12 DataFrame
#  Row │ Full name  First name  ID       Class    Start date    Start time  End  ⋯
#      │ String7    String7     Missing  String7  String15      String15    Stri ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Last01     First01     missing  CS101    Sep 27, 2023  8:30 AM     Sep  ⋯
#    2 │ Last01     First01     missing  CS101    Sep 27, 2023  1:15 PM     Sep
#    3 │ Last01     First01     missing  CS101    Sep 29, 2023  1:15 PM     Sep
#    4 │ Last01     First01     missing  CS101    Oct 3, 2023   8:30 AM     Oct
#    5 │ Last01     First01     missing  CS101    Oct 3, 2023   9:25 AM     Oct  ⋯
#    6 │ Last01     First01     missing  CS101    Dec 8, 2023   1:15 PM     Dec
#    7 │ Last02     First02     missing  CS101    Oct 3, 2023   8:55 AM     Oct
#    8 │ Last02     First02     missing  CS101    Oct 9, 2023   1:15 PM     Oct
#    9 │ Last02     First02     missing  CS101    Oct 10, 2023  8:30 AM     Oct  ⋯
#   10 │ Last02     First02     missing  CS101    Oct 10, 2023  1:15 PM     Oct
#   11 │ Last02     First02     missing  CS101    Oct 11, 2023  1:15 PM     Oct
#   ⋮  │     ⋮          ⋮          ⋮        ⋮          ⋮            ⋮            ⋱
#   41 │ Last08     First08     missing  CS101    Oct 27, 2023  1:15 PM     Oct
#   42 │ Last08     First08     missing  CS101    Nov 21, 2023  8:30 AM     Nov  ⋯
#   43 │ Last09     First09     missing  CS101    Sep 22, 2023  1:15 PM     Sep
#   44 │ Last09     First09     missing  CS101    Sep 29, 2023  1:15 PM     Sep
#   45 │ Last09     First09     missing  CS101    Oct 4, 2023   10:30 AM    Oct
#   46 │ Last09     First09     missing  CS101    Oct 13, 2023  10:30 AM    Oct  ⋯
#   47 │ Last10     First10     missing  CS101    Oct 4, 2023   8:30 AM     Oct
#   48 │ Last10     First10     missing  CS101    Oct 13, 2023  8:30 AM     Oct
#   49 │ Last10     First10     missing  CS101    Oct 20, 2023  8:30 AM     Oct
#   50 │ Last10     First10     missing  CS101    Oct 20, 2023  1:15 PM     Oct  ⋯
#                                                    6 columns and 29 rows omitted

# %%
data[!, "TimeMissed"] = data[!, "EndTime"] - data[!, "StartTime"] 

# Convert to minutes
data[!, "MinutesMissed"] = floor.(Int, Dates.value.(data[!, "TimeMissed"]) / (60 * 10^9))

# Drop variables
select!(data, Not(:TimeMissed ))

display(data)
# Out:
# 50×13 DataFrame
#  Row │ Full name  First name  ID       Class    Start date    Start time  End  ⋯
#      │ String7    String7     Missing  String7  String15      String15    Stri ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Last01     First01     missing  CS101    Sep 27, 2023  8:30 AM     Sep  ⋯
#    2 │ Last01     First01     missing  CS101    Sep 27, 2023  1:15 PM     Sep
#    3 │ Last01     First01     missing  CS101    Sep 29, 2023  1:15 PM     Sep
#    4 │ Last01     First01     missing  CS101    Oct 3, 2023   8:30 AM     Oct
#    5 │ Last01     First01     missing  CS101    Oct 3, 2023   9:25 AM     Oct  ⋯
#    6 │ Last01     First01     missing  CS101    Dec 8, 2023   1:15 PM     Dec
#    7 │ Last02     First02     missing  CS101    Oct 3, 2023   8:55 AM     Oct
#    8 │ Last02     First02     missing  CS101    Oct 9, 2023   1:15 PM     Oct
#    9 │ Last02     First02     missing  CS101    Oct 10, 2023  8:30 AM     Oct  ⋯
#   10 │ Last02     First02     missing  CS101    Oct 10, 2023  1:15 PM     Oct
#   11 │ Last02     First02     missing  CS101    Oct 11, 2023  1:15 PM     Oct
#   ⋮  │     ⋮          ⋮          ⋮        ⋮          ⋮            ⋮            ⋱
#   41 │ Last08     First08     missing  CS101    Oct 27, 2023  1:15 PM     Oct
#   42 │ Last08     First08     missing  CS101    Nov 21, 2023  8:30 AM     Nov  ⋯
#   43 │ Last09     First09     missing  CS101    Sep 22, 2023  1:15 PM     Sep
#   44 │ Last09     First09     missing  CS101    Sep 29, 2023  1:15 PM     Sep
#   45 │ Last09     First09     missing  CS101    Oct 4, 2023   10:30 AM    Oct
#   46 │ Last09     First09     missing  CS101    Oct 13, 2023  10:30 AM    Oct  ⋯
#   47 │ Last10     First10     missing  CS101    Oct 4, 2023   8:30 AM     Oct
#   48 │ Last10     First10     missing  CS101    Oct 13, 2023  8:30 AM     Oct
#   49 │ Last10     First10     missing  CS101    Oct 20, 2023  8:30 AM     Oct
#   50 │ Last10     First10     missing  CS101    Oct 20, 2023  1:15 PM     Oct  ⋯
#                                                    7 columns and 29 rows omitted

# %%
# Create a new DataFrame with the required variables
result_df = combine(groupby(data, [Symbol("Full name"), :StartDate]), :MinutesMissed => sum)

# Rename columns for clarity
rename!(result_df, :MinutesMissed_sum => :TotalMinutesMissed)

# Display the result DataFrame
display(result_df)
# Out:
# 38×3 DataFrame
#  Row │ Full name  StartDate   TotalMinutesMissed
#      │ String7    Date        Int64
# ─────┼───────────────────────────────────────────
#    1 │ Last01     2023-09-27                 330
#    2 │ Last01     2023-09-29                 105
#    3 │ Last01     2023-10-03                 220
#    4 │ Last01     2023-12-08                 105
#    5 │ Last02     2023-10-03                  25
#    6 │ Last02     2023-10-09                 215
#    7 │ Last02     2023-10-10                 210
#    8 │ Last02     2023-10-11                   2
#    9 │ Last02     2023-10-13                  20
#   10 │ Last03     2023-10-10                  36
#   11 │ Last03     2023-10-12                  50
#   ⋮  │     ⋮          ⋮               ⋮
#   29 │ Last08     2023-10-12                  50
#   30 │ Last08     2023-10-27                 330
#   31 │ Last08     2023-11-21                 225
#   32 │ Last09     2023-09-22                 105
#   33 │ Last09     2023-09-29                   5
#   34 │ Last09     2023-10-04                 105
#   35 │ Last09     2023-10-13                 105
#   36 │ Last10     2023-10-04                 105
#   37 │ Last10     2023-10-13                 105
#   38 │ Last10     2023-10-20                 330
#                                   17 rows omitted

# %%
# Scatter plot
scatter(result_df[!, "StartDate"], result_df[!, "Full name"], size=(800, 400), marker=:circle, color=:blue, label="Minutes Missed", xlabel="Start Time", ylabel="Full Name")

# %%
# Group by start time and calculate the frequency for each time
time_summary = combine(groupby(result_df, :StartDate), nrow)

# Display the frequency table
display(time_summary)
# Out:
# 23×2 DataFrame
#  Row │ StartDate   nrow
#      │ Date        Int64
# ─────┼───────────────────
#    1 │ 2023-09-27      2
#    2 │ 2023-09-29      3
#    3 │ 2023-10-03      2
#    4 │ 2023-12-08      1
#    5 │ 2023-10-09      2
#    6 │ 2023-10-10      2
#    7 │ 2023-10-11      1
#    8 │ 2023-10-13      3
#    9 │ 2023-10-12      4
#   10 │ 2023-10-26      3
#   11 │ 2023-11-15      1
#   12 │ 2023-09-22      2
#   13 │ 2023-11-27      1
#   14 │ 2023-12-06      1
#   15 │ 2023-12-07      1
#   16 │ 2023-10-18      1
#   17 │ 2023-10-19      1
#   18 │ 2023-11-23      1
#   19 │ 2023-09-21      1
#   20 │ 2023-10-27      1
#   21 │ 2023-11-21      1
#   22 │ 2023-10-04      2
#   23 │ 2023-10-20      1

# %%
scatter(time_summary[!, "StartDate"], time_summary[!, :nrow], xlabel="Start Time", ylabel="Frequency", label="Frequency")

# %%
bar(time_summary[!, "StartDate"], time_summary[!, :nrow], xlabel="Date", ylabel="Frequency", label="Frequency")

# %%
# Feature engineering: Extract day of the week
result_df[!, "DayOfWeek"] = Dates.dayname.(Dates.Date.(result_df[!, "StartDate"]))

# Filter out weekends and holidays
weekdays_df = result_df[(result_df[!, "DayOfWeek"] .!= "Saturday") .& (result_df[!, "DayOfWeek"] .!= "Sunday"), :]
# Out:
# 38×4 DataFrame
#  Row │ Full name  StartDate   TotalMinutesMissed  DayOfWeek
#      │ String7    Date        Int64               String
# ─────┼──────────────────────────────────────────────────────
#    1 │ Last01     2023-09-27                 330  Wednesday
#    2 │ Last01     2023-09-29                 105  Friday
#    3 │ Last01     2023-10-03                 220  Tuesday
#    4 │ Last01     2023-12-08                 105  Friday
#    5 │ Last02     2023-10-03                  25  Tuesday
#    6 │ Last02     2023-10-09                 215  Monday
#    7 │ Last02     2023-10-10                 210  Tuesday
#    8 │ Last02     2023-10-11                   2  Wednesday
#    9 │ Last02     2023-10-13                  20  Friday
#   10 │ Last03     2023-10-10                  36  Tuesday
#   11 │ Last03     2023-10-12                  50  Thursday
#   ⋮  │     ⋮          ⋮               ⋮               ⋮
#   29 │ Last08     2023-10-12                  50  Thursday
#   30 │ Last08     2023-10-27                 330  Friday
#   31 │ Last08     2023-11-21                 225  Tuesday
#   32 │ Last09     2023-09-22                 105  Friday
#   33 │ Last09     2023-09-29                   5  Friday
#   34 │ Last09     2023-10-04                 105  Wednesday
#   35 │ Last09     2023-10-13                 105  Friday
#   36 │ Last10     2023-10-04                 105  Wednesday
#   37 │ Last10     2023-10-13                 105  Friday
#   38 │ Last10     2023-10-20                 330  Friday
#                                              17 rows omitted

# %%
# Group by student and weekday and count absences
grouped_df = groupby(weekdays_df, [Symbol("Full name"), :DayOfWeek])
count_df = combine(grouped_df, :TotalMinutesMissed => sum => :AbsenceCount)
# Out:
# 27×3 DataFrame
#  Row │ Full name  DayOfWeek  AbsenceCount
#      │ String7    String     Int64
# ─────┼────────────────────────────────────
#    1 │ Last01     Wednesday           330
#    2 │ Last01     Friday              210
#    3 │ Last01     Tuesday             220
#    4 │ Last02     Tuesday             235
#    5 │ Last02     Monday              215
#    6 │ Last02     Wednesday             2
#    7 │ Last02     Friday               20
#    8 │ Last03     Tuesday              36
#    9 │ Last03     Thursday            325
#   10 │ Last03     Wednesday           210
#   11 │ Last04     Friday               17
#   ⋮  │     ⋮          ⋮           ⋮
#   18 │ Last06     Thursday            430
#   19 │ Last07     Thursday              4
#   20 │ Last07     Friday              315
#   21 │ Last08     Thursday             50
#   22 │ Last08     Friday              330
#   23 │ Last08     Tuesday             225
#   24 │ Last09     Friday              215
#   25 │ Last09     Wednesday           105
#   26 │ Last10     Wednesday           105
#   27 │ Last10     Friday              435
#                             6 rows omitted

# %%
# Find the weekday with the maximum absences for each student
max_absence_day_df = combine(groupby(count_df, "Full name"), :AbsenceCount => argmax => :DayOfWeek, :AbsenceCount => maximum => :MaxAbsences)

# Add a column with the corresponding weekday
max_absence_day_df[!, "Weekday"] = Dates.dayname.(Dates.Date.(max_absence_day_df[!, "DayOfWeek"]))

# Display the result
display(max_absence_day_df)
# Out:
# 10×4 DataFrame
#  Row │ Full name  DayOfWeek  MaxAbsences  Weekday
#      │ String7    Int64      Int64        String
# ─────┼────────────────────────────────────────────
#    1 │ Last01             1          330  Monday
#    2 │ Last02             1          235  Monday
#    3 │ Last03             2          325  Tuesday
#    4 │ Last04             2          775  Tuesday
#    5 │ Last05             1          248  Monday
#    6 │ Last06             1          430  Monday
#    7 │ Last07             2          315  Tuesday
#    8 │ Last08             2          330  Tuesday
#    9 │ Last09             1          215  Monday
#   10 │ Last10             2          435  Tuesday

# %%
# Create a DataFrame with all the dates you want to include
all_dates = DataFrame(StartDate = Date(2023, 9, 19):Date(2023, 12, 15))

# Filter weekdays
all_dates = filter(row -> Dates.dayofweek(row.StartDate) in 2:6, all_dates)
# Out:
# 64×1 DataFrame
#  Row │ StartDate
#      │ Date
# ─────┼────────────
#    1 │ 2023-09-19
#    2 │ 2023-09-20
#    3 │ 2023-09-21
#    4 │ 2023-09-22
#    5 │ 2023-09-23
#    6 │ 2023-09-26
#    7 │ 2023-09-27
#    8 │ 2023-09-28
#    9 │ 2023-09-29
#   10 │ 2023-09-30
#   11 │ 2023-10-03
#   ⋮  │     ⋮
#   55 │ 2023-12-02
#   56 │ 2023-12-05
#   57 │ 2023-12-06
#   58 │ 2023-12-07
#   59 │ 2023-12-08
#   60 │ 2023-12-09
#   61 │ 2023-12-12
#   62 │ 2023-12-13
#   63 │ 2023-12-14
#   64 │ 2023-12-15
#    43 rows omitted

# %%
describe(result_df)
# Out:
# 4×7 DataFrame
#  Row │ variable            mean     min         median      max         nmissi ⋯
#      │ Symbol              Union…   Any         Any         Any         Int64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Full name                    Last01                  Last10             ⋯
#    2 │ StartDate                    2023-09-21  2023-10-12  2023-12-08
#    3 │ TotalMinutesMissed  154.289  2           105.0       610
#    4 │ DayOfWeek                    Friday                  Wednesday
#                                                                2 columns omitted

# %% [markdown]
# ## Create a database with all school days

# %%
display(result_df)
# Out:
# 38×4 DataFrame
#  Row │ Full_name  StartDate   TotalMinutesMissed  DayOfWeek
#      │ String7    Date        Int64               String
# ─────┼──────────────────────────────────────────────────────
#    1 │ Last01     2023-09-27                 330  Wednesday
#    2 │ Last01     2023-09-29                 105  Friday
#    3 │ Last01     2023-10-03                 220  Tuesday
#    4 │ Last01     2023-12-08                 105  Friday
#    5 │ Last02     2023-10-03                  25  Tuesday
#    6 │ Last02     2023-10-09                 215  Monday
#    7 │ Last02     2023-10-10                 210  Tuesday
#    8 │ Last02     2023-10-11                   2  Wednesday
#    9 │ Last02     2023-10-13                  20  Friday
#   10 │ Last03     2023-10-10                  36  Tuesday
#   11 │ Last03     2023-10-12                  50  Thursday
#   ⋮  │     ⋮          ⋮               ⋮               ⋮
#   29 │ Last08     2023-10-12                  50  Thursday
#   30 │ Last08     2023-10-27                 330  Friday
#   31 │ Last08     2023-11-21                 225  Tuesday
#   32 │ Last09     2023-09-22                 105  Friday
#   33 │ Last09     2023-09-29                   5  Friday
#   34 │ Last09     2023-10-04                 105  Wednesday
#   35 │ Last09     2023-10-13                 105  Friday
#   36 │ Last10     2023-10-04                 105  Wednesday
#   37 │ Last10     2023-10-13                 105  Friday
#   38 │ Last10     2023-10-20                 330  Friday
#                                              17 rows omitted

# %%
using DataFrames
using Dates

# Rename the DataFrame
df = result_df

rename!(df,:"Full name" => :Full_name)

# Keep only the rows where DayOfWeek is "Friday"
df_filtered = filter(row -> row."Full name" == "Last01", df)
# Out:
# ArgumentError: Tried renaming :Full name to :Full_name, when :Full name does not exist in the data frame.
#
# Stacktrace:
#  [1] rename!(x::DataFrames.Index, nms::Vector{Pair{Symbol, Symbol}})
#    @ DataFrames ~/.julia/packages/DataFrames/58MUJ/src/other/index.jl:91
#  [2] rename!
#    @ ~/.julia/packages/DataFrames/58MUJ/src/abstractdataframe/abstractdataframe.jl:216 [inlined]
#  [3] rename!(df::DataFrame, args::Pair{Symbol, Symbol})
#    @ DataFrames ~/.julia/packages/DataFrames/58MUJ/src/abstractdataframe/abstractdataframe.jl:253
#  [4] top-level scope
#    @ In[87]:7

# %% [markdown]
# ## SANDBOX

# %%
using DataFrames
using Dates

# Define the input DataFrame
df_full = DataFrame(
    Full_name = String[],
    StartDate = Date[],
    TotalMinutesMissed = Int64[],
    DayOfWeek = String[]
)

# Define the date range
date_range = Date(2023, 9, 27):Day(1):Date(2023, 12, 8)

# Populate the DataFrame with the specified formats
for date in date_range
    push!(df_full, [
        "Last01",
        date,
        0,
        Dates.format(date, "EEEE")
    ])
end

df_full = filter(row -> row.DayOfWeek != "Saturday" && row.DayOfWeek != "Sunday", df_full)


# Print the resulting DataFrame
println(df_full)
# Out:
# 53×4 DataFrame
#  Row │ Full_name  StartDate   TotalMinutesMissed  DayOfWeek
#      │ String     Date        Int64               String
# ─────┼──────────────────────────────────────────────────────
#    1 │ Last01     2023-09-27                   0  Wednesday
#    2 │ Last01     2023-09-28                   0  Thursday
#    3 │ Last01     2023-09-29                   0  Friday
#    4 │ Last01     2023-10-02                   0  Monday
#    5 │ Last01     2023-10-03                   0  Tuesday
#    6 │ Last01     2023-10-04                   0  Wednesday
#    7 │ Last01     2023-10-05                   0  Thursday
#    8 │ Last01     2023-10-06                   0  Friday
#    9 │ Last01     2023-10-09                   0  Monday
#   10 │ Last01     2023-10-10                   0  Tuesday
#   11 │ Last01     2023-10-11                   0  Wednesday
#   12 │ Last01     2023-10-12                   0  Thursday
#   13 │ Last01     2023-10-13                   0  Friday
#   14 │ Last01     2023-10-16                   0  Monday
#   15 │ Last01     2023-10-17                   0  Tuesday
#   16 │ Last01     2023-10-18                   0  Wednesday
#   17 │ Last01     2023-10-19                   0  Thursday
#   18 │ Last01     2023-10-20                   0  Friday
#   19 │ Last01     2023-10-23                   0  Monday
#   20 │ Last01     2023-10-24                   0  Tuesday
#   21 │ Last01     2023-10-25                   0  Wednesday
#   22 │ Last01     2023-10-26                   0  Thursday
#   23 │ Last01     2023-10-27                   0  Friday
#   24 │ Last01     2023-10-30                   0  Monday
#   25 │ Last01     2023-10-31                   0  Tuesday
#   26 │ Last01     2023-11-01                   0  Wednesday
#   27 │ Last01     2023-11-02                   0  Thursday
#   28 │ Last01     2023-11-03                   0  Friday
#   29 │ Last01     2023-11-06                   0  Monday
#   30 │ Last01     2023-11-07                   0  Tuesday
#   31 │ Last01     2023-11-08                   0  Wednesday
#   32 │ Last01     2023-11-09                   0  Thursday
#   33 │ Last01     2023-11-10                   0  Friday
#   34 │ Last01     2023-11-13                   0  Monday
#   35 │ Last01     2023-11-14                   0  Tuesday
#   36 │ Last01     2023-11-15                   0  Wednesday
#   37 │ Last01     2023-11-16                   0  Thursday
#   38 │ Last01     2023-11-17                   0  Friday
#   39 │ Last01     2023-11-20                   0  Monday
#   40 │ Last01     2023-11-21                   0  Tuesday
#   41 │ Last01     2023-11-22                   0  Wednesday
#   42 │ Last01     2023-11-23                   0  Thursday
#   43 │ Last01     2023-11-24                   0  Friday
#   44 │ Last01     2023-11-27                   0  Monday
#   45 │ Last01     2023-11-28                   0  Tuesday
#   46 │ Last01     2023-11-29                   0  Wednesday
#   47 │ Last01     2023-11-30                   0  Thursday
#   48 │ Last01     2023-12-01                   0  Friday
#   49 │ Last01     2023-12-04                   0  Monday
#   50 │ Last01     2023-12-05                   0  Tuesday
#   51 │ Last01     2023-12-06                   0  Wednesday
#   52 │ Last01     2023-12-07                   0  Thursday
#   53 │ Last01     2023-12-08                   0  Friday

# %%
# Merge DataFrame A into DataFrame B, overwriting values in B with values in A
#df_complete = join(df_full, df_filtered, on = :TotalMinutesMissed, kind = :left, makeunique = true)

#df_complete = innerjoin(df_full, df_filtered, on = :TotalMinutesMissed, makeunique=true)

merged = outerjoin(df_full, df_filtered, on = :TotalMinutesMissed, makeunique=true)
# Out:
# 57×7 DataFrame
#  Row │ Full_name  StartDate   TotalMinutesMissed  DayOfWeek  Full name  StartD ⋯
#      │ String?    Date?       Int64               String?    String7?   Date?  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Last01     2023-09-27                   0  Wednesday  missing    missin ⋯
#    2 │ Last01     2023-09-28                   0  Thursday   missing    missin
#    3 │ Last01     2023-09-29                   0  Friday     missing    missin
#    4 │ Last01     2023-10-02                   0  Monday     missing    missin
#    5 │ Last01     2023-10-03                   0  Tuesday    missing    missin ⋯
#    6 │ Last01     2023-10-04                   0  Wednesday  missing    missin
#    7 │ Last01     2023-10-05                   0  Thursday   missing    missin
#    8 │ Last01     2023-10-06                   0  Friday     missing    missin
#    9 │ Last01     2023-10-09                   0  Monday     missing    missin ⋯
#   10 │ Last01     2023-10-10                   0  Tuesday    missing    missin
#   11 │ Last01     2023-10-11                   0  Wednesday  missing    missin
#   ⋮  │     ⋮          ⋮               ⋮               ⋮          ⋮           ⋮ ⋱
#   48 │ Last01     2023-12-01                   0  Friday     missing    missin
#   49 │ Last01     2023-12-04                   0  Monday     missing    missin ⋯
#   50 │ Last01     2023-12-05                   0  Tuesday    missing    missin
#   51 │ Last01     2023-12-06                   0  Wednesday  missing    missin
#   52 │ Last01     2023-12-07                   0  Thursday   missing    missin
#   53 │ Last01     2023-12-08                   0  Friday     missing    missin ⋯
#   54 │ missing    missing                    330  missing    Last01     2023-0
#   55 │ missing    missing                    105  missing    Last01     2023-0
#   56 │ missing    missing                    220  missing    Last01     2023-1
#   57 │ missing    missing                    105  missing    Last01     2023-1 ⋯
#                                                    2 columns and 36 rows omitted

# %%
using DataFrames

# Create two dataframes
df_a = DataFrame(A = [1, 2], B = [4, 5])
df_b = DataFrame(A = [1, 2, 3], B = [4, 11, 6])

# Merge the two dataframes
merged = outerjoin(df_a, df_b, on = :A, makeunique=true)

# Print the merged dataframe
print(merged)
# Out:
# 3×3 DataFrame
#  Row │ A      B        B_1
#      │ Int64  Int64?   Int64?
# ─────┼────────────────────────
#    1 │     1        4       4
#    2 │     2        5      11
#    3 │     3  missing       6

# %%
# Out:
# type Array has no field update
#
# Stacktrace:
#  [1] getproperty(x::Vector{Union{Missing, Int64}}, f::Symbol)
#    @ Base ./Base.jl:37
#  [2] top-level scope
#    @ In[5]:2
