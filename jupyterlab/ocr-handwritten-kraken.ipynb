# %% [markdown]
# # Machine Learning and Handwritten Scripts

# %% [markdown]
# kraken ( https://kraken.re ) is supported with Python 3.11.9 (not with 3.14 that is currently installed on my computer).
#
# In case the shared library libperl.so.5.40 is missing in your sytem (as it was on mine) :
# ```
# sudo dnf install perl-Digest-SHA perl-libs
# ```
#
# Install Python virtual environment (`pyenv`)
#
# ```
# # Install pyenv if you don’t have it yet
# curl https://pyenv.run | bash   # follow the post‑install instructions
#
# # Install a supported Python version, e.g. 3.11.9
# pyenv install 3.11.9
#
# # Create a virtual environment with that version
# pyenv virtualenv 3.11.9 kraken-dev
# pyenv activate kraken-dev   # or `pyenv local kraken-dev` inside the project dir
# ```
#
# Now your terminal should look like :
# ```
# (kraken-dev) username@fedora:~/sandbox$
# ```
#
# Install the latest development branch (see [kraken website](https://kraken.re/main/index.html) )
# ```
# git clone https://github.com/mittagessen/kraken.git
# cd kraken
# pip install --editable .
#
# ```
#
# List all teh available (pre-trained) kraken models :
#
# ```
# kraken list
# ```
#
# Download the default model for printed French (and other language ) text. This is the model to do the actual recognition of characters :
#
# ```
# kraken get 10.5281/zenodo.13788176
# ```
#
# Run the following command in the terminal :
#
# ```
# kraken -i page_004.tif test2.txt segment -bl ocr -m /home/tarikz/.local/share/htrmopo/78d7d26e-50b3-55f8-b839-c7a882ea2053/McCATMuS_nfd_nofix_V1.mlmodel
# ```

# %%
import subprocess

subprocess.run(["kraken", "-i", "/home/tarikz/sandbox/page_004.tif", "/home/tarikz/sandbox/page_004.txt", "segment", "-bl", "ocr", "-m", "/home/tarikz/.local/share/htrmopo/78d7d26e-50b3-55f8-b839-c7a882ea2053/McCATMuS_nfd_nofix_V1.mlmodel"])
# Out:
# 2025-12-14 21:07:16.188678: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-14 21:07:16.212324: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-14 21:07:16.212356: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-14 21:07:16.212987: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
